# %%
# Replace 'your_file.csv' with the actual path to your CSV file
csv_file = '/kaggle/input/pad-uefs-20/PAD-UFES-20_metadata.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#   patient_id  lesion_id  smoke  drink background_father background_mother  \
# 0   PAT_1516       1765    NaN    NaN               NaN               NaN
# 1     PAT_46        881  False  False         POMERANIA         POMERANIA
# 2   PAT_1545       1867    NaN    NaN               NaN               NaN
# 3   PAT_1989       4061    NaN    NaN               NaN               NaN
# 4    PAT_684       1302  False   True         POMERANIA         POMERANIA
#
#    age pesticide  gender skin_cancer_history  ... diameter_2 diagnostic  \
# 0    8       NaN     NaN                 NaN  ...        NaN        NEV
# 1   55     False  FEMALE                True  ...        5.0        BCC
# 2   77       NaN     NaN                 NaN  ...        NaN        ACK
# 3   75       NaN     NaN                 NaN  ...        NaN        ACK
# 4   79     False    MALE                True  ...        5.0        BCC
#
#     itch   grew   hurt  changed  bleed elevation                 img_id  \
# ...

# %%
import os
source_folder = '/kaggle/input/part1datasett/kaggle/working/PAD-UFES-20_images_part_11forzip'
destination_folder = '/kaggle/working/Dataset'

if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# %%
unique_values = pd.unique(df['diagnostic'])

# %%
unique_values
# Out:
# array(['NEV', 'BCC', 'ACK', 'SEK', 'SCC', 'MEL'], dtype=object)

# %%
for diag in unique_values:
    dest_folder = '/kaggle/working/maidatasetfolder/'+diag
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

# %%
def save_image(image, filename):
  """
    Saves unscaled Tensor Images.
    Args:
      image: 3D image tensor. [height, width, channels]
      filename: Name of the file to save.
  """
  if not isinstance(image, Image.Image):
    image = tf.clip_by_value(image, 0, 255)
    image = Image.fromarray(tf.cast(image, tf.uint8).numpy())
  image.save("%s.png" % filename)
  print("Saved as %s.png" % filename)

# %%
import os
import shutil
import pandas as pd

csv_file = "/kaggle/input/pad-uefs-20/PAD-UFES-20_metadata.csv"
image_folder = "/kaggle/input/part1datasett/kaggle/working/PAD-UFES-20_images_part_11forzip"
destination_folder = '/kaggle/working/Dataset'

df = pd.read_csv("/kaggle/input/pad-uefs-20/PAD-UFES-20_metadata.csv")


for index,row in df.iterrows():
    image_id = str(row['img_id'])
    diagnosis = str(row['diagnostic'])
    
    destination_folder = os.path.join(destination_folder,diagnosis)
    
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
    
    source_path = os.path.join(image_folder,image_id)
    destination_path = os.path.join(destination_folder,image_id)
    
    shutil.copy(source_path,destination_path)
    
    i = 0
    
    print(f"image {i} is saved on {destination_folder}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 24
#      21 source_path = os.path.join(image_folder,image_id)
#      22 destination_path = os.path.join(destination_folder,image_id)
# ---> 24 shutil.copy(source_path,destination_path)
#      26 i = 0
#      28 print(f"image {i} is saved on {destination_folder}")
#
# File /opt/conda/lib/python3.10/shutil.py:417, in copy(src, dst, follow_symlinks)
#     415 if os.path.isdir(dst):
#     416     dst = os.path.join(dst, os.path.basename(src))
# --> 417 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File /opt/conda/lib/python3.10/shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
# ...

# %%
import os
sourcePath = "/kaggle/input/pad-uefs-20/PAD-UFES-20_metadata.csv"
destination = "/kaggle/working/data"
if not os.path.exists(destination):
    os.makedirs(destination)

# %%
import shutil
shutil.copy(sourcePath,destination)
# Out:
# '/kaggle/working/data/PAD-UFES-20_metadata.csv'

# %% [markdown]
# <a href="/kaggle/working/data/PAD-UFES-20_metadata.csv"> Download File </a>
